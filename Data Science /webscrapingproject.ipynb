# %%
# #Project azenda is sorting and ideatifing the all reviews from flipkart website using below liabraries 
# import requests
# from bs4 import BeautifulSoup as bs
# from urllib.request import urlopen
# import logging

# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen
import logging

# %%
flipcart_url="https://www.flipkart.com/search?q="+"nokia11"

# %%
flipcart_url
# Out:
# 'https://www.flipkart.com/search?q=nokia11'

# %%
# here we are clicking on url and its running it and we create a auto one without clicking it have run

# %%
urlclient=urlopen(flipcart_url)

# %%
urlclient

# %%
# urlclient.read()
#below all codes are from webpafe which we puuled from flipkart website to view webpage source code
#and its not in human readable we have to clean it bu saving urlclient.read() this in another variable

# %%
flipkart_page=urlclient.read()

# %%
# flipkart_page run this with BeautifulSoup as bs to look Good

# %%
# bs(flipkart_page,'html.parser') now create varaible for this

# %%
flipkart_html=bs(flipkart_page,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...
